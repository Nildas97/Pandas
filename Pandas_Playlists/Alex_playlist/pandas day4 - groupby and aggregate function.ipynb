# %% [markdown]
# # Group by

# %% [markdown]
# ## importing library

# %%
import pandas as pd

# %% [markdown]
# ## importing  dataset

# %%
df = pd.read_csv(r"D:\Data Science\archive\winequality_white.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ## group by on single column

# %%
groupby_df = df.groupby("quality")

# %%
groupby_df.mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %% [markdown]
# ## popular aggregate functions

# %% [markdown]
# ### aggregate function - mean()

# %%
df.groupby("quality").mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %% [markdown]
# ### aggregate function - count()

# %%
df.groupby("quality").count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                   20                20           20              20
# 4                  163               163          163             163
# 5                 1457              1457         1457            1457
# 6                 2198              2198         2198            2198
# 7                  880               880          880             880
# 8                  175               175          175             175
# 9                    5                 5            5               5
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3               20                   20                    20       20    20
# 4              163                  163                   163      163   163
# 5             1457                 1457                  1457     1457  1457
# 6             2198                 2198                  2198     2198  2198
# ...

# %% [markdown]
# ### aggregate function - min()

# %%
df.groupby("quality").min()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                  4.2              0.17         0.21             0.7
# 4                  4.8              0.11         0.00             0.7
# 5                  4.5              0.10         0.00             0.6
# 6                  3.8              0.08         0.00             0.7
# 7                  4.2              0.08         0.01             0.9
# 8                  3.9              0.12         0.04             0.8
# 9                  6.6              0.24         0.29             1.6
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.022                  5.0                  19.0  0.99110  2.87
# 4            0.013                  3.0                  10.0  0.98920  2.83
# 5            0.009                  2.0                   9.0  0.98722  2.79
# 6            0.015                  3.0                  18.0  0.98758  2.72
# ...

# %% [markdown]
# ### aggregate function - max()

# %%
df.groupby("quality").max()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                 11.8             0.640         0.47           16.20
# 4                 10.2             1.100         0.88           17.55
# 5                 10.3             0.905         1.00           23.50
# 6                 14.2             0.965         1.66           65.80
# 7                  9.2             0.760         0.74           19.25
# 8                  8.2             0.660         0.74           14.80
# 9                  9.1             0.360         0.49           10.60
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.244                289.0                 440.0  1.00010  3.55
# 4            0.290                138.5                 272.0  1.00040  3.72
# 5            0.346                131.0                 344.0  1.00241  3.79
# 6            0.255                112.0                 294.0  1.03898  3.81
# ...

# %% [markdown]
# ### aggregate function - sum()

# %%
df.groupby("quality").sum()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3               152.00             6.665         6.72          127.85
# 4              1162.10            62.140        49.59          754.40
# 5             10102.80           440.030       491.96        10687.05
# 6             15029.20           572.720       742.98        14158.65
# 7              5926.55           231.235       286.55         4564.10
# 8              1165.00            48.545        57.14          992.50
# 9                37.10             1.490         1.93           20.60
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# quality
# 3            1.086               1066.5                3412.0    19.897680
# 4            8.166               3807.5               20420.5   162.067100
# 5           75.103              53081.5              219868.0  1450.097565
# 6           99.388              78360.0              301230.0  2184.727045
# ...

# %% [markdown]
# ### agg() function

# %%
df.groupby("quality").agg({'fixed acidity' : ['mean', 'max', 'sum', 'min', 'count'], 'volatile acidity' : ['mean', 'max', 'sum', 'min', 'count']})
# Out:
#         fixed acidity                            volatile acidity         \
#                  mean   max       sum  min count             mean    max
# quality
# 3            7.600000  11.8    152.00  4.2    20         0.333250  0.640
# 4            7.129448  10.2   1162.10  4.8   163         0.381227  1.100
# 5            6.933974  10.3  10102.80  4.5  1457         0.302011  0.905
# 6            6.837671  14.2  15029.20  3.8  2198         0.260564  0.965
# 7            6.734716   9.2   5926.55  4.2   880         0.262767  0.760
# 8            6.657143   8.2   1165.00  3.9   175         0.277400  0.660
# 9            7.420000   9.1     37.10  6.6     5         0.298000  0.360
#
#
#              sum   min count
# quality
# 3          6.665  0.17    20
# 4         62.140  0.11   163
# 5        440.030  0.10  1457
# 6        572.720  0.08  2198
# 7        231.235  0.08   880
# 8         48.545  0.12   175
# 9          1.490  0.24     5

# %% [markdown]
# ### group by on multiple column

# %%
df.groupby(['quality', 'alcohol']).agg({'fixed acidity' : ['mean', 'max', 'sum', 'min', 'count'], 'volatile acidity' : ['mean', 'max', 'sum', 'min', 'count']})
# Out:
#                 fixed acidity                         volatile acidity         \
#                          mean   max   sum   min count             mean    max
# quality alcohol
# 3       8.0               4.2   4.2   4.2   4.2     1            0.215  0.215
#         8.5               9.1   9.1   9.1   9.1     1            0.590  0.590
#         9.1               7.7   7.9  15.4   7.5     2            0.480  0.640
#         9.4               6.7   6.7   6.7   6.7     1            0.250  0.250
#         9.6              10.3  10.3  10.3  10.3     1            0.170  0.170
# ...                       ...   ...   ...   ...   ...              ...    ...
# 9       10.4              9.1   9.1   9.1   9.1     1            0.270  0.270
#         12.4              6.6   6.6   6.6   6.6     1            0.360  0.360
#         12.5              7.4   7.4   7.4   7.4     1            0.240  0.240
#         12.7              6.9   6.9   6.9   6.9     1            0.360  0.360
# ...

# %% [markdown]
# ### describe() function

# %%
df.groupby(['quality', 'alcohol']).describe()
# Out:
#                 fixed acidity                                                \
#                         count  mean       std   min   25%   50%   75%   max
# quality alcohol
# 3       8.0               1.0   4.2       NaN   4.2   4.2   4.2   4.2   4.2
#         8.5               1.0   9.1       NaN   9.1   9.1   9.1   9.1   9.1
#         9.1               2.0   7.7  0.282843   7.5   7.6   7.7   7.8   7.9
#         9.4               1.0   6.7       NaN   6.7   6.7   6.7   6.7   6.7
#         9.6               1.0  10.3       NaN  10.3  10.3  10.3  10.3  10.3
# ...                       ...   ...       ...   ...   ...   ...   ...   ...
# 9       10.4              1.0   9.1       NaN   9.1   9.1   9.1   9.1   9.1
#         12.4              1.0   6.6       NaN   6.6   6.6   6.6   6.6   6.6
#         12.5              1.0   7.4       NaN   7.4   7.4   7.4   7.4   7.4
#         12.7              1.0   6.9       NaN   6.9   6.9   6.9   6.9   6.9
# ...
