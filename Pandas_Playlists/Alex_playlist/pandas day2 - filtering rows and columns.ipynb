# %% [markdown]
# # Filtering and Ordering

# %% [markdown]
# ## importing library

# %%
import pandas as pd

# %% [markdown]
# ## importing dataset

# %%
df = pd.read_csv(r"D:\Data Science\Dataset\data5\Visadataset.csv")
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## filtering column using conditional operators

# %%
df[df['case_id'] <= 'EZYV100']
# Out:
#     case_id      continent education_of_employee has_job_experience  \
# 0    EZYV01           Asia           High School                  N
# 1    EZYV02           Asia              Master's                  Y
# 2    EZYV03           Asia            Bachelor's                  N
# 3    EZYV04           Asia            Bachelor's                  N
# 4    EZYV05         Africa              Master's                  Y
# 5    EZYV06           Asia              Master's                  Y
# 6    EZYV07           Asia            Bachelor's                  N
# 7    EZYV08  North America            Bachelor's                  Y
# 8    EZYV09           Asia            Bachelor's                  N
# 9    EZYV10         Europe             Doctorate                  Y
# 99  EZYV100           Asia              Master's                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# ...

# %% [markdown]
#  ## filtering data

# %% [markdown]
# ### filtering using .isin() function

# %%
continents = ['Asia', 'Africa']

df[df['continent'].isin(continents)]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### filtering using .contains() function

# %%
df[df['education_of_employee'].str.contains('High School')]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 11        EZYV12           Asia           High School                  Y
# 15        EZYV16           Asia           High School                  Y
# 23        EZYV24  North America           High School                  N
# 27        EZYV28           Asia           High School                  Y
# ...          ...            ...                   ...                ...
# 25463  EZYV25464           Asia           High School                  N
# 25465  EZYV25466  North America           High School                  N
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## filtering using .set_index() function

# %%
df2 = df.set_index('continent')
df2
# Out:
#              case_id education_of_employee has_job_experience  \
# continent
# Asia          EZYV01           High School                  N
# Asia          EZYV02              Master's                  Y
# Asia          EZYV03            Bachelor's                  N
# Asia          EZYV04            Bachelor's                  N
# Africa        EZYV05              Master's                  Y
# ...              ...                   ...                ...
# Asia       EZYV25476            Bachelor's                  Y
# Asia       EZYV25477           High School                  Y
# Asia       EZYV25478              Master's                  Y
# Asia       EZYV25479              Master's                  Y
# Asia       EZYV25480            Bachelor's                  Y
#
#           requires_job_training  no_of_employees  yr_of_estab  \
# continent
# Asia                          N            14513         2007
# Asia                          N             2412         2002
# ...

# %% [markdown]
# ## filtering using .filter() function

# %%
df2.filter(items = ['region_of_employment', 'education_of_employee'])
# Out:
#           region_of_employment education_of_employee
# continent
# Asia                      West           High School
# Asia                 Northeast              Master's
# Asia                      West            Bachelor's
# Asia                      West            Bachelor's
# Africa                   South              Master's
# ...                        ...                   ...
# Asia                     South            Bachelor's
# Asia                 Northeast           High School
# Asia                     South              Master's
# Asia                      West              Master's
# Asia                   Midwest            Bachelor's
#
# [25480 rows x 2 columns]

# %% [markdown]
# ### here we can mention axis value, which determines which axis it is following. <br> axis = 0, means it is row wise. <br> axis = 1, means it is column wise.

# %% [markdown]
# ## filtering using .filter() function and axis = 0

# %%
df2.filter(items = ['has_job_experience'], axis=0)
# Out:
# C:\Users\nilut\AppData\Local\Temp\ipykernel_17252\1890147067.py:1: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   df2.filter(items = ['has_job_experience'], axis=0)
# Empty DataFrame
# Columns: [case_id, education_of_employee, has_job_experience, requires_job_training, no_of_employees, yr_of_estab, region_of_employment, prevailing_wage, unit_of_wage, full_time_position, case_status]
# Index: []

# %% [markdown]
# ## filtering using .filter() function and axis = 1

# %%
df2.filter(items = ['region_of_employment', 'education_of_employee'], axis=1)
# Out:
#           region_of_employment education_of_employee
# continent
# Asia                      West           High School
# Asia                 Northeast              Master's
# Asia                      West            Bachelor's
# Asia                      West            Bachelor's
# Africa                   South              Master's
# ...                        ...                   ...
# Asia                     South            Bachelor's
# Asia                 Northeast           High School
# Asia                     South              Master's
# Asia                      West              Master's
# Asia                   Midwest            Bachelor's
#
# [25480 rows x 2 columns]

# %% [markdown]
# ## filtering using filter() function & like

# %% [markdown]
# ### items method in the above code and like method in the below code works similar

# %%
df2.filter(like='Africa', axis= 0)
# Out:
#              case_id education_of_employee has_job_experience  \
# continent
# Africa        EZYV05              Master's                  Y
# Africa        EZYV19              Master's                  Y
# Africa        EZYV75              Master's                  Y
# Africa       EZYV195              Master's                  Y
# Africa       EZYV243            Bachelor's                  N
# ...              ...                   ...                ...
# Africa     EZYV25386             Doctorate                  Y
# Africa     EZYV25409              Master's                  Y
# Africa     EZYV25444            Bachelor's                  N
# Africa     EZYV25447              Master's                  N
# Africa     EZYV25475             Doctorate                  N
#
#           requires_job_training  no_of_employees  yr_of_estab  \
# continent
# Africa                        N             1082         2005
# Africa                        N             4743         2004
# ...

# %% [markdown]
# ## filtering using loc() function - label based

# %%
df2.loc['Europe']
# Out:
#              case_id education_of_employee has_job_experience  \
# continent
# Europe        EZYV10             Doctorate                  Y
# Europe        EZYV17              Master's                  Y
# Europe        EZYV25             Doctorate                  Y
# Europe        EZYV37           High School                  Y
# Europe        EZYV38              Master's                  Y
# ...              ...                   ...                ...
# Europe     EZYV25436            Bachelor's                  N
# Europe     EZYV25449             Doctorate                  Y
# Europe     EZYV25461              Master's                  Y
# Europe     EZYV25463            Bachelor's                  N
# Europe     EZYV25467            Bachelor's                  Y
#
#           requires_job_training  no_of_employees  yr_of_estab  \
# continent
# Europe                        N             2251         1995
# Europe                        N            76638         1991
# ...

# %% [markdown]
# ## filtering using iloc() function - integer based

# %%
df2.iloc[2251]
# Out:
# case_id                    EZYV2252
# education_of_employee    Bachelor's
# has_job_experience                N
# requires_job_training             N
# no_of_employees                2988
# yr_of_estab                    2001
# region_of_employment           West
# prevailing_wage            773.3891
# unit_of_wage                   Hour
# full_time_position                Y
# case_status                  Denied
# Name: North America, dtype: object

# %% [markdown]
# ## filtering using .sort_values() for one column in ascending order

# %%
df[df['case_id'] <= 'EZYV100'].sort_values(by='case_id', ascending=True)
# Out:
#     case_id      continent education_of_employee has_job_experience  \
# 0    EZYV01           Asia           High School                  N
# 1    EZYV02           Asia              Master's                  Y
# 2    EZYV03           Asia            Bachelor's                  N
# 3    EZYV04           Asia            Bachelor's                  N
# 4    EZYV05         Africa              Master's                  Y
# 5    EZYV06           Asia              Master's                  Y
# 6    EZYV07           Asia            Bachelor's                  N
# 7    EZYV08  North America            Bachelor's                  Y
# 8    EZYV09           Asia            Bachelor's                  N
# 9    EZYV10         Europe             Doctorate                  Y
# 99  EZYV100           Asia              Master's                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# ...

# %% [markdown]
# ### here, column case_id less than 100 gets ordered in ascending order.

# %% [markdown]
# ## filtering using .sort_values() for one column in descending order

# %%
df[df['case_id'] <= 'EZYV100'].sort_values(by='case_id', ascending=False)
# Out:
#     case_id      continent education_of_employee has_job_experience  \
# 99  EZYV100           Asia              Master's                  N
# 9    EZYV10         Europe             Doctorate                  Y
# 8    EZYV09           Asia            Bachelor's                  N
# 7    EZYV08  North America            Bachelor's                  Y
# 6    EZYV07           Asia            Bachelor's                  N
# 5    EZYV06           Asia              Master's                  Y
# 4    EZYV05         Africa              Master's                  Y
# 3    EZYV04           Asia            Bachelor's                  N
# 2    EZYV03           Asia            Bachelor's                  N
# 1    EZYV02           Asia              Master's                  Y
# 0    EZYV01           Asia           High School                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# ...

# %% [markdown]
# ### here, column case_id less than 100 gets ordered in descending order.

# %% [markdown]
# ## filtering using .sort_values() for multiple column in ascending order

# %%
df[df['case_id'] < 'EZYV100'].sort_values(by=['continent', 'education_of_employee'], ascending=True)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 4  EZYV05         Africa              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 6  EZYV07           Asia            Bachelor's                  N
# 8  EZYV09           Asia            Bachelor's                  N
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 9  EZYV10         Europe             Doctorate                  Y
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 4                     N             1082         2005                South
# 2                     Y            44444         2008                 West
# ...

# %% [markdown]
# ### here, the column capital get ordered by ascending order and Country remain same.

# %% [markdown]
# ## filtering using .sort_values() for multiple column in ascending order or descending order

# %%
df[df['case_id'] < 'EZYV100'].sort_values(by=['continent', 'education_of_employee'], ascending=[False, True])
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 7  EZYV08  North America            Bachelor's                  Y
# 9  EZYV10         Europe             Doctorate                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 6  EZYV07           Asia            Bachelor's                  N
# 8  EZYV09           Asia            Bachelor's                  N
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 4  EZYV05         Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 7                     N             3035         1924                 West
# 9                     N             2251         1995                South
# ...

# %% [markdown]
# ### sorting the columns in ascending or descending depends on which column gets the priority of getting first place. <br> column Continent gets the priority of first place and gets sorted too but column Capital remains same.

# %% [markdown]
# # practice session

# %%
df1 = pd.read_csv(r"D:\Data Science\Dataset\data3\googleplaystore.csv")
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## filtering using the conditional operators

# %%
df1[df1['Reviews'] >= '100']
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
Tier1 = ['HEALTH_AND_FITNESS', 'LIFESTYLE']

df1[df1['Category'].isin(Tier1)]
# Out:
#                                                   App            Category  \
# 1256                      Home Workout - No Equipment  HEALTH_AND_FITNESS
# 1257                   Step Counter - Calorie Counter  HEALTH_AND_FITNESS
# 1258         Lose Belly Fat in 30 Days - Flat Stomach  HEALTH_AND_FITNESS
# 1259   Pedometer - Step Counter Free & Calorie Burner  HEALTH_AND_FITNESS
# 1260                Six Pack in 30 Days - Abs Workout  HEALTH_AND_FITNESS
# ...                                               ...                 ...
# 10773                                        FQ India           LIFESTYLE
# 10797                           Fuel Rewards® program           LIFESTYLE
# 10805                                   Scoreboard FR           LIFESTYLE
# 10808                              lesparticuliers.fr           LIFESTYLE
# 10840   iHoroscope - 2018 Daily Horoscope & Astrology           LIFESTYLE
#
#        Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
df1.filter(items=['Category','Genres'])
# Out:
#                   Category                     Genres
# 0           ART_AND_DESIGN               Art & Design
# 1           ART_AND_DESIGN  Art & Design;Pretend Play
# 2           ART_AND_DESIGN               Art & Design
# 3           ART_AND_DESIGN               Art & Design
# 4           ART_AND_DESIGN    Art & Design;Creativity
# ...                    ...                        ...
# 10836               FAMILY                  Education
# 10837               FAMILY                  Education
# 10838              MEDICAL                    Medical
# 10839  BOOKS_AND_REFERENCE          Books & Reference
# 10840            LIFESTYLE                  Lifestyle
#
# [10841 rows x 2 columns]

# %%
df1.filter(like=['Rating'])
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\nilut\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nilut\AppData\Local\Temp\ipykernel_17252\2627668077.py", line 1, in <module>
#     df1.filter(like=['Rating'])
#   File "C:\Users\nilut\anaconda3\lib\site-packages\pandas\core\generic.py", line 5461, in filter
#     values = labels.map(f)
#   File "C:\Users\nilut\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 6361, in map
#     new_values = self._map_values(mapper, na_action=na_action)
#   File "C:\Users\nilut\anaconda3\lib\site-packages\pandas\core\base.py", line 890, in _map_values
#     new_values = map_f(values, mapper)
#   File "pandas\_libs\lib.pyx", line 2924, in pandas._libs.lib.map_infer
# ...
